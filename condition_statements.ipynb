# %% [markdown]
# <a href="https://colab.research.google.com/github/maniprasad84/Day-1/blob/main/condition_statements.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
num = 10
#declare a variable

if num > 0:
    print("The number is positive.")
#if codition
elif num < 0:
    print("The number is negative.")
#elif condition
else:
    print("The number is zero.")
#else condition
