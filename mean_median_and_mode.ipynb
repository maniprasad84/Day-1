# %%
nums = [10, 20, 30, 40, 50]

mean = sum(nums) / len(nums)
print("Mean =", mean)
# Out:
# Mean = 30.0

# %%
nums = [10, 20, 30, 40, 50]

nums.sort()
n = len(nums)

median = nums[n//2]   # for odd number of elements
print("Median =", median)
# Out:
# Median = 30

# %%
import random
import statistics
numbers = [random.randint(1, 100) for _ in range(10)]

mean_value = statistics.mean(numbers)

print("Random numbers:", numbers)
print("Mean:", mean_value)
# Out:
# Random numbers: [65, 43, 38, 55, 47, 93, 85, 96, 86, 33]
# Mean: 64.1

# %%
data = [1, 2, 2, 3, 4, 4, 4, 5]

mode = max(set(data), key=data.count)

print("Mode:", mode)
# Out:
# Mode: 4
