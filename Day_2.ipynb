# %%
x = ["TCOL_abort", "login", "HomePage_02", "Verify_login"]

for name in x:
    if any(char.isdigit() for char in name):
        print(name)
# Out:
# HomePage_02

# %%
y = "Sky is blue,and I have wear a blue dress"

words = y.replace(",", "").split()

for word in words:
    if words.count(word) > 1:
        print(word)
        break
print(word)
# Out:
# dress
